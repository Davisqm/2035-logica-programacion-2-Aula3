# %% [markdown]
# <a href="https://colab.research.google.com/github/Davisqm/2035-logica-programacion-2-Aula3/blob/master/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU

# %% [markdown]
# # Dataset

# %%
df_pasajeros = pd.read_csv("/content/alura-pasajeros.csv")
df_pasajeros.head()
# Out:
#         tiempo  pasajeros
# 0  2010.000000        112
# 1  2010.083333        118
# 2  2010.166667        132
# 3  2010.250000        129
# 4  2010.333333        121

# %%
df_pasajeros.tail()
# Out:
#           tiempo  pasajeros
# 139  2021.583333        606
# 140  2021.666667        508
# 141  2021.750000        461
# 142  2021.833333        390
# 143  2021.916667        432

# %%
sns.lineplot(data=df_pasajeros, x = "tiempo", y ="pasajeros")

# %%
ss = StandardScaler()
dfn_pasajeros=ss.fit_transform(df_pasajeros)

# %%
dfn_pasajeros[:5,:]
# Out:
# array([[-1.72006415, -1.40777884],
#        [-1.69600731, -1.35759023],
#        [-1.67195047, -1.24048348],
#        [-1.64789363, -1.26557778],
#        [-1.62383679, -1.33249593]])

# %%
dfn_pasajeros[-5:,:]
# Out:
# array([[1.62383679, 2.72441656],
#        [1.64789363, 1.9046693 ],
#        [1.67195047, 1.5115252 ],
#        [1.69600731, 0.91762667],
#        [1.72006415, 1.26894693]])

# %%
x = dfn_pasajeros[:,0]
y = dfn_pasajeros[:,1]

# %%
sns.lineplot(x = x, y =y)

# %%
split_n = int(0.9*len(x))
x_train = x[0:split_n]
x_test = x[split_n:]
y_train = y[0:split_n]
y_test = y[split_n:]
x_train.shape, y_test.shape
# Out:
# ((129,), (15,))

# %%
sns.lineplot(x = x_train, y =y_train, label="Entrenamiento")
sns.lineplot(x = x_test, y =y_test, label="Test")

# %% [markdown]
# # Red Neuronal

# %%
rn_lineal = Sequential()
rn_lineal.add( Dense(1, input_dim = 1, kernel_initializer = "ones", use_bias=True) )
rn_lineal.compile(loss="mean_squared_error", optimizer="adam")

# %%
rn_lineal.fit(x_train,y_train)
# Out:
# 5/5 [==============================] - 1s 4ms/step - loss: 0.1286

# %%
y_predicted = rn_lineal.predict(x_train)
y_predicted.shape
# Out:
# (129, 1)

# %%
sns.lineplot(x = x_train, y =y_train, label="Entrenamiento")
sns.lineplot(x = x_train, y =y_predicted.ravel(), label="Predicción")

# %%
y_predicted_test = rn_lineal.predict(x_test)
y_predicted_test.shape
# Out:
# (15, 1)

# %%
sns.lineplot(x = x_test, y =y_test, label="Entrenamiento")
sns.lineplot(x = x_test, y =y_predicted_test.ravel(), label="Predicción")

# %% [markdown]
# ## Transformación de datos

# %%
def invertir_scala(tiempo,pasajeros,escalador):
  tmp = {"tiempo":tiempo,"pasajeros":pasajeros}
  df_tmp = pd.DataFrame(data=tmp)
  data_invertida = escalador.inverse_transform(df_tmp)
  df_final = pd.DataFrame(data_invertida)
  df_final.columns=["tiempo","pasajeros"]
  return df_final

# %%
df_training = invertir_scala(x_train,y_predicted.ravel(), ss)
df_predicted = invertir_scala(x_test,y_predicted_test.ravel(), ss)

# %%
sns.lineplot(data=df_pasajeros, x = "tiempo", y ="pasajeros", label="Datos")
sns.lineplot(data=df_training, x = "tiempo", y ="pasajeros", label="Entrenamiento")
sns.lineplot(data=df_predicted, x = "tiempo", y ="pasajeros", label="Predicción")

# %% [markdown]
# # Red Neuronal Compleja

# %%
rn = Sequential()
rn.add( Dense(8, input_dim = 1) )
rn.add( Dense(8) )
rn.add( Dense(1) )
rn.compile(loss="mean_squared_error", optimizer="adam")
rn.fit(x_train,y_train, epochs=100)
y_predicted = rn.predict(x_train)
y_predicted_test = rn.predict(x_test)
df_training = invertir_scala(x_train,y_predicted.ravel(), ss)
df_predicted = invertir_scala(x_test,y_predicted_test.ravel(), ss)

# %%
sns.lineplot(data=df_pasajeros, x = "tiempo", y ="pasajeros", label="Datos")
sns.lineplot(data=df_training, x = "tiempo", y ="pasajeros", label="Entrenamiento")
sns.lineplot(data=df_predicted, x = "tiempo", y ="pasajeros", label="Predicción")

# %%
rn_relu = Sequential()
rn_relu.add( Dense(8, input_dim = 1, activation="relu") )
rn_relu.add( Dense(8, activation="relu") )
rn_relu.add( Dense(1) )
rn_relu.compile(loss="mean_squared_error", optimizer="adam")
rn_relu.fit(x_train,y_train, epochs=100)
y_predicted = rn_relu.predict(x_train)
y_predicted_test = rn_relu.predict(x_test)
df_training = invertir_scala(x_train,y_predicted.ravel(), ss)
df_predicted = invertir_scala(x_test,y_predicted_test.ravel(), ss)

# %%
sns.lineplot(data=df_pasajeros, x = "tiempo", y ="pasajeros", label="Datos")
sns.lineplot(data=df_training, x = "tiempo", y ="pasajeros", label="Entrenamiento")
sns.lineplot(data=df_predicted, x = "tiempo", y ="pasajeros", label="Predicción")

# %% [markdown]
# # Cambio de perspectiva

# %%
def lag_variable(pasajeros,n_lag):
  x_train,y_train=[],[]
  for i in range(n_lag,len(pasajeros)):
    y_train.append(pasajeros[i])
    x_train.append(list(pasajeros[i-n_lag:i]))
  return x_train, y_train

# %%
x_train_new,y_train_new = lag_variable(y_train,1)

# %%
print(x_train_new[:5])
print(y_train_new[:5])
# Out:
# [[-1.4077788408280638], [-1.3575902326797062], [-1.2404834803335385], [-1.2655777844077172], [-1.3324959286055273]]
# [-1.3575902326797062, -1.2404834803335385, -1.2655777844077172, -1.3324959286055273, -1.2153891762593596]

# %%
rn_tanh = Sequential()
rn_tanh.add( Dense(8, input_dim = 1, activation="tanh") )
rn_tanh.add( Dense(8, activation="tanh") )
rn_tanh.add( Dense(1) )
rn_tanh.compile(loss="mean_squared_error", optimizer="adam")
rn_tanh.fit(x_train_new,y_train_new, epochs=100)
y_predicted_new = rn_tanh.predict(x_train_new)

# %%
x_test_new,y_test_new = lag_variable(y_test,1)
y_predicted_test_new = rn_tanh.predict(x_test_new)

# %%
rango1 = range(0,len(y_train_new))
rango2 = range(len(y_train_new),len(y_train_new)+len(y_test_new))
sns.lineplot(x=rango1, y=y_train_new,label="Entrenamiento")
sns.lineplot(x=rango2, y=y_test_new,label="Test")
sns.lineplot(x=rango1, y=y_predicted_new.ravel(),label="Predicción Entrenamiento")
sns.lineplot(x=rango2, y=y_predicted_test_new.ravel(),label="Predicción Test")

# %% [markdown]
# # Multiples Ventanas de Tiempo

# %%
n_lag=3
x_train_new,y_train_new = lag_variable(y_train,n_lag)
rn_tanh = Sequential()
rn_tanh.add( Dense(8, input_dim = n_lag, activation="tanh") )
rn_tanh.add( Dense(64, activation="tanh") )
rn_tanh.add( Dense(1) )
rn_tanh.compile(loss="mean_squared_error", optimizer="adam")
rn_tanh.fit(x_train_new,y_train_new, epochs=200)
y_predicted_new = rn_tanh.predict(x_train_new)
x_test_new,y_test_new = lag_variable(y_test,n_lag)
y_predicted_test_new = rn_tanh.predict(x_test_new)

# %%
rango1 = range(0,len(y_train_new))
rango2 = range(len(y_train_new),len(y_train_new)+len(y_test_new))
# sns.lineplot(x=rango1, y=y_train_new,label="Entrenamiento")
# sns.lineplot(x=rango2, y=y_test_new,label="Test")
sns.lineplot(x=rango1, y=y_predicted_new.ravel(),label="Predicción Entrenamiento")
sns.lineplot(x=rango2, y=y_predicted_test_new.ravel(),label="Predicción Test")

# %%
sns.lineplot(x=rango1, y=y_train_new,label="Entrenamiento")
sns.lineplot(x=rango2, y=y_test_new,label="Test")

# %% [markdown]
# # Alura Bikes

# %%
df_bicicletas=pd.read_csv("/content/alura-bicicletas.csv")
df_bicicletas.head()
# Out:
#                  Fecha  Cantidad  Temperatura  sensacao  Humedad  Viento  \
# 0  2015-01-04 00:00:00       182          3.0       2.0     93.0     6.0
# 1  2015-01-04 01:00:00       138          3.0       2.5     93.0     5.0
# 2  2015-01-04 02:00:00       134          2.5       2.5     96.5     0.0
# 3  2015-01-04 03:00:00        72          2.0       2.0    100.0     0.0
# 4  2015-01-04 04:00:00        47          2.0       0.0     93.0     6.5
#
#    Clima  Feriado  Fin_semana  Estación
# 0      3        0           1         3
# 1      1        0           1         3
# 2      1        0           1         3
# 3      1        0           1         3
# 4      1        0           1         3

# %%
df_bicicletas.tail()
# Out:
#                      Fecha  Cantidad  Temperatura  sensacao  Humedad  Viento  \
# 17409  2017-01-03 19:00:00      1042          5.0       1.0     81.0    19.0
# 17410  2017-01-03 20:00:00       541          5.0       1.0     81.0    21.0
# 17411  2017-01-03 21:00:00       337          5.5       1.5     78.5    24.0
# 17412  2017-01-03 22:00:00       224          5.5       1.5     76.0    23.0
# 17413  2017-01-03 23:00:00       139          5.0       1.0     76.0    22.0
#
#        Clima  Feriado  Fin_semana  Estación
# 17409      3        0           0         3
# 17410      4        0           0         3
# 17411      4        0           0         3
# 17412      4        0           0         3
# 17413      2        0           0         3

# %%
df_bicicletas["Fecha"]=pd.to_datetime(df_bicicletas["Fecha"])

# %%
sns.lineplot(data=df_bicicletas,x="Fecha",y="Cantidad")
# Out:
# <Axes: xlabel='Fecha', ylabel='Cantidad'>

# %%
split = 0.8
rango = int(len(df_bicicletas)*split)
y_train = df_bicicletas["Cantidad"].iloc[:rango].values
y_test = df_bicicletas["Cantidad"].iloc[rango:].values

# %%
sns.lineplot(x=range(0,rango),y=y_train,label="Entrenamiento")
sns.lineplot(x=range(rango,len(df_bicicletas)),y=y_test,label="Test")
# Out:
# <Axes: >

# %%
y_train.shape
# Out:
# (13931,)

# %%
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)
y_train.shape
# Out:
# (13931, 1)

# %%
ss_bicicleta = StandardScaler()
y_train = ss_bicicleta.fit_transform(y_train)
y_test = ss_bicicleta.transform(y_test)

# %%
sns.lineplot(x=range(0,rango),y=y_train.ravel(),label="Entrenamiento")
sns.lineplot(x=range(rango,len(df_bicicletas)),y=y_test.ravel(),label="Test")
# Out:
# <Axes: >

# %%
x_train_bike, y_train_bike = lag_variable(y_train.ravel(), 10 )
x_test_bike, y_test_bike = lag_variable(y_test.ravel(), 10 )

x_train_bike, y_train_bike = np.array(x_train_bike), np.array(y_train_bike)
x_test_bike, y_test_bike = np.array(x_test_bike), np.array(y_test_bike)

print(x_train_bike.shape,x_test_bike.shape,y_train_bike.shape,y_test_bike.shape)
# Out:
# (13921, 10) (3473, 10) (13921,) (3473,)

# %% [markdown]
# # Redes Neuronales Recurrentes

# %%
x_train_bike = x_train_bike.reshape( -1, x_train_bike.shape[1], 1 )
print(x_train_bike.shape)
# Out:
# (13921, 10, 1)

# %%
rnr = Sequential()
rnr.add ( SimpleRNN( 8,activation="tanh", input_shape=(x_train_bike.shape[1],x_train_bike.shape[2],) ) )
rnr.add ( Dense (1) )
rnr.compile(loss="mse",optimizer="adam")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
rnr.fit(x_train_bike,y_train_bike,epochs=20)
# Out:
# Epoch 1/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.5759
# Epoch 2/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1784
# Epoch 3/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1546
# Epoch 4/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1384
# Epoch 5/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1116
# Epoch 6/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1012
# Epoch 7/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0932
# Epoch 8/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0918
# Epoch 9/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0837
# Epoch 10/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0814
# Epoch 11/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0796
# Epoch 12/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0782
# Epoch 13/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0784
# Epoch 14/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0721
# Epoch 15/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0682
# Epoch 16/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0679
# Epoch 17/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0666
# Epoch 18/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0696
# Epoch 19/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0659
# Epoch 20/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0683

# %%
y_predict_bike = rnr.predict(x_train_bike)
# Out:
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
rango_bike = (5100,5200)
rango_x = range(rango_bike[0],rango_bike[1])
rango_y = y_train_bike[rango_bike[0]:rango_bike[1]]
rango_y_predict = y_predict_bike.ravel()[rango_bike[0]:rango_bike[1]]
sns.lineplot(x=rango_x,y=rango_y,label="Entrenamiento")
sns.lineplot(x=rango_x,y=rango_y_predict,label="Predicción")
# Out:
# <Axes: >

# %% [markdown]
# # Redes Neuronales Recurrente LSTM

# %%
rnr_lstm = Sequential()
rnr_lstm.add ( LSTM( 8,activation="tanh", input_shape=(x_train_bike.shape[1], x_train_bike.shape[2]),))
rnr_lstm.add ( Dense (1) )
rnr_lstm.compile(loss="mse",optimizer="adam")
rnr_lstm.fit(x_train_bike,y_train_bike,epochs=20)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.7543
# Epoch 2/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2428
# Epoch 3/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1518
# Epoch 4/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1352
# Epoch 5/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1278
# Epoch 6/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1162
# Epoch 7/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1145
# Epoch 8/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1087
# Epoch 9/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1107
# Epoch 10/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0963
# Epoch 11/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0949
# Epoch 12/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0917
# Epoch 13/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0851
# Epoch 14/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0839
# Epoch 15/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0915
# Epoch 16/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0826
# Epoch 17/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0816
# Epoch 18/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0811
# Epoch 19/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0807
# Epoch 20/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0781

# %%
y_predict_bike = rnr_lstm.predict(x_train_bike)
# Out:
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
rango_bike = (5100,5200)
rango_x = range(rango_bike[0],rango_bike[1])
rango_y = y_train_bike[rango_bike[0]:rango_bike[1]]
rango_y_predict = y_predict_bike.ravel()[rango_bike[0]:rango_bike[1]]
sns.lineplot(x=rango_x,y=rango_y,label="Entrenamiento")
sns.lineplot(x=rango_x,y=rango_y_predict,label="Predicción")
# Out:
# <Axes: >

# %% [markdown]
# ## Resultados de la RNN
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# GRU overfitting

# %%
rn_gru = Sequential()
rn_gru.add ( GRU( 8,activation="tanh", input_shape=(x_train_bike.shape[1], x_train_bike.shape[2]),))
rn_gru.add ( Dense (1) )
rn_gru.compile(loss="mse",optimizer="adam")
historia =rn_gru.fit(x_train_bike,y_train_bike,epochs=20, validation_data=(x_test_bike,y_test_bike))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.7787 - val_loss: 0.3365
# Epoch 2/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2564 - val_loss: 0.1844
# Epoch 3/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.1534 - val_loss: 0.1337
# Epoch 4/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.1137 - val_loss: 0.1131
# Epoch 5/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0963 - val_loss: 0.1030
# Epoch 6/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0945 - val_loss: 0.0782
# Epoch 7/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0741 - val_loss: 0.0672
# Epoch 8/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0632 - val_loss: 0.0609
# Epoch 9/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0574 - val_loss: 0.0580
# Epoch 10/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0553 - val_loss: 0.0508
# Epoch 11/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0513 - val_loss: 0.0481
# Epoch 12/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0490 - val_loss: 0.0494
# Epoch 13/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0474 - val_loss: 0.0461
# Epoch 14/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0438 - val_loss: 0.0456
# Epoch 15/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0424 - val_loss: 0.0436
# Epoch 16/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 0.0444 - val_loss: 0.0431
# Epoch 17/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0435 - val_loss: 0.0411
# Epoch 18/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.0448 - val_loss: 0.0419
# Epoch 19/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0408 - val_loss: 0.0405
# Epoch 20/20
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0415 - val_loss: 0.0430

# %%
sns.lineplot(data=historia.history["loss"] , label="Entrenamiento")
sns.lineplot(data=historia.history["val_loss"] , label="Validación")
# Out:
# <Axes: >
